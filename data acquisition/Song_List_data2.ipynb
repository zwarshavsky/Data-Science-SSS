# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/user/Documents/GitHub/Datasets/Spotify/master_data/track_features.csv")

# %%
colnames=["trackId","songId","artist","track"]

df2 = pd.read_csv("./data/million_songs_dataset.txt",sep="<SEP>",names=colnames,header=None)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df2.head()
# Out:
#               trackId              songId            artist              track
# 0  TRMMMYQ128F932D901  SOQMMHC12AB0180CB8  Faster Pussy cat       Silent Night
# 1  TRMMMKD128F425225D  SOVFVAK12A8C1350D9  Karkkiautomaatti        Tanssi vaan
# 2  TRMMMRX128F93187D9  SOGTUKN12AB017F4F1    Hudson Mohawke  No One Could Ever
# 3  TRMMMCH128F425532C  SOBNYVR12A8C13558C       Yerba Brava      Si Vos Querés
# 4  TRMMMWA128F426B589  SOHSBXH12A8C13B0DF        Der Mystic   Tangle Of Aspens

# %%
df2.describe()
# Out:
#                    trackId              songId           artist   track
# count              1000000             1000000          1000000  999985
# unique             1000000              999056            72665  702000
# top     TRHMHDQ128F92F0A71  SOODBWM12A6D4F6B0E  Michael Jackson   Intro
# freq                     1                   3              194    1511

# %%
df.head()
# Out:
#                                  track_id    duration  release_year  \
# 0  t_2e8f4b71-8a0b-4b9c-b7d8-fb5208e87f9f  326.013336          1971
# 1  t_dae2ec0e-ec7b-4b3e-b60c-4a884d0eccb0  147.813324          1963
# 2  t_cf0164dd-1531-4399-bfa6-dec19cd1fedc  110.400002          1974
# 3  t_0f90acc7-d5c5-4e53-901d-55610fbd090c  237.653336          1988
# 4  t_36b9ad02-095a-443d-a697-6c7285d9410a  174.600006          1987
#
#    us_popularity_estimate  acousticness  beat_strength  bounciness  \
# 0               99.582885      0.716209       0.366495    0.332605
# 1               97.272035      0.839460       0.362212    0.389829
# 2               99.620384      0.054673       0.495002    0.589378
# 3               96.796830      0.042606       0.389634    0.359044
# 4               97.905891      0.249982       0.513640    0.485435
#
#    danceability  dyn_range_mean    energy  ...  time_signature   valence  \
# 0      0.439835        5.805774  0.238847  ...               4  0.223395
# 1      0.507580        6.845427  0.420476  ...               4  0.484702
# 2      0.552311        9.361949  0.842938  ...               4  0.818441
# 3      0.585673        6.068578  0.665398  ...               4  0.594829
# 4      0.635095        7.198735  0.408715  ...               4  0.591289
#
#    acoustic_vector_0  acoustic_vector_1  acoustic_vector_2  acoustic_vector_3  \
# 0           0.146012          -0.706908           0.259496           0.481157
# 1           0.039554          -0.539554           0.105141           0.692589
# 2           0.083863          -0.242108          -0.014258           0.096396
# 3           0.192498           0.340039           0.034846          -0.389794
# 4           0.270586          -0.411061           0.165898           0.225652
#
#   acoustic_vector_4  acoustic_vector_5  acoustic_vector_6  acoustic_vector_7
# 0          0.238427          -0.098389          -0.254960          -0.227383
# 1          0.226047          -0.468162           0.164389          -0.769024
# 2          0.417641          -0.050576          -0.204757          -0.172563
# 3          0.518381           0.185008          -0.079907          -0.016978
# 4          0.335518          -0.036643          -0.016300          -0.446870
#
# [5 rows x 30 columns]

# %%
df["track_id"][:10]
# Out:
# 0    t_2e8f4b71-8a0b-4b9c-b7d8-fb5208e87f9f
# 1    t_dae2ec0e-ec7b-4b3e-b60c-4a884d0eccb0
# 2    t_cf0164dd-1531-4399-bfa6-dec19cd1fedc
# 3    t_0f90acc7-d5c5-4e53-901d-55610fbd090c
# 4    t_36b9ad02-095a-443d-a697-6c7285d9410a
# 5    t_cbf7084a-0ab7-40b2-8e47-a010580e8d15
# 6    t_2ee16606-ba70-419f-a437-7c6ee2b8ec26
# 7    t_3e80fb67-dc0b-4a97-aff8-88d82f452f9d
# 8    t_f9b9a072-8dae-4816-bfd6-d91fc75a5744
# 9    t_d076e5fa-174c-4614-a1b8-371bd0ea3343
# Name: track_id, dtype: object

# %%
df.describe(include="all")
# Out:
#                                       track_id      duration  release_year  \
# count                                  1853311  1.853311e+06  1.853311e+06
# unique                                 1853311           NaN           NaN
# top     t_74c72aef-f593-445e-8e50-06322788d961           NaN           NaN
# freq                                         1           NaN           NaN
# mean                                       NaN  2.332751e+02  2.009259e+03
# std                                        NaN  1.086198e+02  1.103782e+01
# min                                        NaN  3.000095e+01  1.950000e+03
# 25%                                        NaN  1.768273e+02  2.006000e+03
# 50%                                        NaN  2.178956e+02  2.013000e+03
# 75%                                        NaN  2.671304e+02  2.017000e+03
# max                                        NaN  1.799815e+03  2.018000e+03
#
#         us_popularity_estimate  acousticness  beat_strength    bounciness  \
# count             1.853311e+06  1.853311e+06   1.853311e+06  1.853311e+06
# unique                     NaN           NaN            NaN           NaN
# top                        NaN           NaN            NaN           NaN
# freq                       NaN           NaN            NaN           NaN
# mean              9.557489e+01  3.469483e-01   4.617319e-01  4.791076e-01
# std               2.735883e+00  3.426890e-01   1.717286e-01  1.989990e-01
# min               9.000000e+01  0.000000e+00   0.000000e+00  0.000000e+00
# 25%               9.338338e+01  2.661495e-02   3.316267e-01  3.207484e-01
# 50%               9.575712e+01  2.202808e-01   4.592793e-01  4.794221e-01
# 75%               9.792292e+01  6.529128e-01   5.852491e-01  6.340019e-01
# max               1.000000e+02  9.957964e-01   9.999525e-01  9.850921e-01
#
#         danceability  dyn_range_mean        energy  ...  time_signature  \
# count   1.853311e+06    1.853311e+06  1.853311e+06  ...    1.853311e+06
# unique           NaN             NaN           NaN  ...             NaN
# top              NaN             NaN           NaN  ...             NaN
# freq             NaN             NaN           NaN  ...             NaN
# mean    5.564984e-01    7.848231e+00  5.920562e-01  ...    3.873969e+00
# std     1.858682e-01    2.679272e+00  2.602121e-01  ...    4.859001e-01
# min     0.000000e+00    0.000000e+00  0.000000e+00  ...    0.000000e+00
# 25%     4.327063e-01    5.823167e+00  4.100748e-01  ...    4.000000e+00
# 50%     5.725539e-01    7.518892e+00  6.264951e-01  ...    4.000000e+00
# 75%     6.975461e-01    9.476678e+00  8.074375e-01  ...    4.000000e+00
# max     9.978067e-01    5.119650e+01  9.999825e-01  ...    5.000000e+00
#
#              valence  acoustic_vector_0  acoustic_vector_1  acoustic_vector_2  \
# count   1.853311e+06       1.853311e+06       1.853311e+06       1.853311e+06
# unique           NaN                NaN                NaN                NaN
# top              NaN                NaN                NaN                NaN
# freq             NaN                NaN                NaN                NaN
# mean    4.815779e-01      -1.043758e-01       1.544666e-02       5.953267e-02
# std     2.724881e-01       4.323172e-01       3.607482e-01       2.803449e-01
# min     0.000000e+00      -1.163774e+00      -1.171400e+00      -8.858698e-01
# 25%     2.522356e-01      -4.082216e-01      -1.760900e-01      -1.470539e-01
# 50%     4.736272e-01      -3.985430e-02       8.452337e-02       1.289347e-01
# 75%     7.052386e-01       1.916600e-01       2.833644e-01       2.745741e-01
# max     9.999900e-01       1.000457e+00       8.624035e-01       6.395299e-01
#
#         acoustic_vector_3 acoustic_vector_4  acoustic_vector_5  \
# count        1.853311e+06      1.853311e+06       1.853311e+06
# unique                NaN               NaN                NaN
# top                   NaN               NaN                NaN
# freq                  NaN               NaN                NaN
# mean         5.321750e-02      2.276128e-02       7.696181e-04
# std          3.822637e-01      4.107625e-01       2.117887e-01
# min         -8.994451e-01     -1.081056e+00      -1.055477e+00
# 25%         -2.350117e-01     -3.121311e-01      -9.005713e-02
# 50%          6.218451e-02     -1.688186e-02       4.288397e-02
# 75%          2.833329e-01      3.725263e-01       1.477068e-01
# max          1.202647e+00      1.000955e+00       4.130149e-01
#
#         acoustic_vector_6  acoustic_vector_7
# count        1.853311e+06       1.853311e+06
# unique                NaN                NaN
# top                   NaN                NaN
# freq                  NaN                NaN
# mean        -2.482889e-02      -1.454615e-03
# std          3.743991e-01       3.872072e-01
# min         -8.022487e-01      -1.178501e+00
# 25%         -3.157318e-01      -2.703560e-01
# 50%         -9.843637e-02      -3.869237e-03
# 75%          2.060100e-01       2.219634e-01
# max          1.092165e+00       1.204228e+00
#
# [11 rows x 30 columns]

# %%
import pyechonest

# %%
# !pwd
# Out:
# /Users/user/Documents/GitHub/Lambda/Data-Science-SSS/data acquisition

# %%
df2.to_pickle("./song_list.pkl")

# %% [markdown]
# # Explore MusicBrainzDB

# %%
musicbrainz = pd.read_csv("/Users/user/Downloads/mbdump/mbdump/track",sep='\t')

# %%
musicbrainz.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6e5049a3120d> in <module>
# ----> 1 musicbrainz.shape
#
# NameError: name 'musicbrainz' is not defined

# %%
musicbrainz.head()

# %%
musicbrainz.describe()

# %% [markdown]
# # Load Sqlite3 Db into Pandas

# %%
import sqlite3
import pandas as pd

con = sqlite3.connect("./song_list3.sqlite3")
df = pd.read_sql_query("SELECT * from File", con)

# %%
df.head()
# Out:
#                    songid              artist              track  \
# 0  5PS5dpaLogPzYU9hWiWyZb    Karkkiautomaatti        Tanssi vaan
# 1  41RpZW2lxAdnqDd2nMBzLQ      Hudson Mohawke  No One Could Ever
# 2  2poHURuOfVNbzZdivAwtOH          Der Mystic   Tangle Of Aspens
# 3  1jg9hZnReygpBvV2axGuPy  Sasha / Turbulence   We Have Got Love
# 4  3GsS8jzoixpCnp4jDWCEvb          Kris Kross  2 Da Beat Ch'yall
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.487   0.678   9.0    -7.780   1.0       0.0495      0.001300
# 1         0.662   0.823   4.0    -1.711   0.0       0.0662      0.000045
# 2         0.430   0.960   5.0    -7.741   0.0       0.0431      0.000725
# 3         0.663   0.677   3.0    -4.117   0.0       0.0755      0.245000
# 4         0.859   0.741  11.0   -12.329   0.0       0.2710      0.002760
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.0551    0.0846    0.870  149.940     157307.0             4.0
# 1            0.9520    0.3430    0.621  177.745     138960.0             4.0
# 2            0.9250    0.1230    0.225  140.001     514290.0             4.0
# 3            0.0000    0.3500    0.879  152.085     212413.0             4.0
# 4            0.0000    0.3250    0.529   98.082     221200.0             4.0

# %%
df.to_csv ('./data/sample.csv', index = None, header=True)

# %% [markdown]
# # For Search Lookups

# %%
df2[df2["artist"].str.contains("Mission Of Burma")]
# Out:
#                    trackId              songId            artist  \
# 326314                                               Dirt
# 336407                                           Devotion
# 337966                                           Progress
# 344262                                        Sing-A-Long
# 349015                              Anti Aircraft Warning
# 409343                                           Dumbells
# 412594                                        Eyes Of Men
# 418662               Thats How I Escaped My Certain Fate
# 433382                         The Ballad of Johnny Burma
# 453204                                             Forget
# ...                                                   ...
# 581356                           All World Cowboy Romance
# 582894                                          Fun World
# 603787                                      Peking Spring
# 610716                                            Tremelo
# 639175                                           Trem Two
# 662982                                    Forget Yourself
# 670006                               Laugh The World Away
# 684306                                  Heart Of Darkness
# 695630                         One Day We Will Live There
# 705214                                Smoldering Fuselage
# 714515                                      He Is_ She Is
# 716883                                      Peking Spring
# 730471                                          ok/no Way
# 742039                                     Einsteins Day
# 768973                                    Foreign Country
# 797303                                           Progress
# 812008                                         Blackboard
# 819788                                           Nu Disco
# 831399                                              Train
# 834151                                          Max Ernst
# 842671                                         Hunt Again
# 852871                           This Is Not A Photograph
# 852994                                   1_ 2_ 3_ Partyy!
# 870334                                       Comes Undone
# 883769                                            Blunder
# 895019                           Learn How [Live Detroit]
# 941663                                            Secrets
# 949532                                          Execution
# 950290                                         Good Cheer
# 976685                           This Is Not A Photograph
#
# [75 rows x 4 columns]

# %%
df2[66786:66787]
# Out:
#                   trackId              songId            artist  \
# 66786  TRWSWKQ128F933D1C4  SOVVPVO12AB018621A  Mission Of Burma
#
#                     track
# 66786  Active In The Yard

# %%
df3 = df2[66787:]

# %%
df3.to_pickle("./song_list2.pkl")

# %%
df3.shape
# Out:
# (933213, 4)

# %%
df5 = pd.read_csv("./song_list5.csv")

# %%
df5.head()
# Out:
#                    songid       artist                    track  danceability  \
# 0  5X4Qm0rVLcZeeO4tSDmBg3   Jack Bruce  Running Thro' Our Hands         0.456
# 1  1pNpt53PZPet9dvJN3RKGr   Prefuse 73        Parachute Panador         0.535
# 2  3oxz2oCzAWdPzA6In2zA5u  Pasion Vega   La Gata Bajo La Lluvia         0.294
# 3  05JGVUwt7XJk5FPqH0Wsch   Jonny Lang             Walking Away         0.563
# 4  3xdgCFMTn6ut8fZYxfAuR0         Skye         All the Promises         0.358
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.255  9.0   -15.805   1.0       0.0480       0.94600          0.170000
# 1   0.806  7.0   -10.289   1.0       0.0642       0.00436          0.019100
# 2   0.482  5.0    -6.406   1.0       0.0430       0.46300          0.000000
# 3   0.631  0.0    -5.144   1.0       0.0324       0.06350          0.000008
# 4   0.611  2.0    -9.752   0.0       0.0454       0.51500          0.000468
#
#    liveness  valence    tempo  duration_ms  time_signature
# 0     0.951   0.0532  116.424     253067.0             4.0
# 1     0.457   0.3760   90.089      63733.0             4.0
# 2     0.335   0.2040  166.693     255280.0             3.0
# 3     0.163   0.5400  115.657     254827.0             4.0
# 4     0.149   0.1640  171.596     256933.0             4.0

# %%
df5.tail()
# Out:
#                        songid           artist          track  danceability  \
# 49980  1K2ca2dSGuhDCe2uqBNCo2            Adeva    I Thank You         0.797
# 49981  0HMQQflKAzVC4ZpeO0a1pm    Kidz Bop Kids     Move Along         0.655
# 49982  5V6bkhWzVJsKchObfqi5oo  The Procussions   Miss January         0.426
# 49983  1zzRJsvY32lHgIRnSWEFx7               U2      The Ocean         0.508
# 49984  6t9dKp7Nf1t4HpYXOdeVNl           Lambda  Hold On Tight         0.689
#
#        energy   key  loudness  mode  speechiness  acousticness  \
# 49980   0.331  10.0   -17.076   0.0       0.0724       0.01850
# 49981   0.706   3.0    -8.143   1.0       0.0577       0.07260
# 49982   0.780  10.0    -6.016   0.0       0.4020       0.00978
# 49983   0.292   3.0   -15.106   0.0       0.0319       0.87500
# 49984   0.765   9.0    -9.246   0.0       0.0332       0.04870
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 49980           0.00003    0.0316   0.7270  119.964     225573.0
# 49981           0.00000    0.1050   0.6480  109.971     240387.0
# 49982           0.00000    0.2060   0.5850  191.050     192440.0
# 49983           0.33700    0.1170   0.1470   84.860      95093.0
# 49984           0.89200    0.1070   0.0872  133.011     751644.0
#
#        time_signature
# 49980             4.0
# 49981             4.0
# 49982             4.0
# 49983             4.0
# 49984             4.0

# %%
df2[df2["artist"].str.contains("Lambda","Hold On Tight")]
# Out:
#                    trackId              songId  \
# 6558    TRMCIHJ128F149AC0C  SOEWNXO12A6D4FA1FB
# 8892    TRMRYFP128F932632E  SOMDBMC12AB01817BD
# 70537   TRWDLLJ12903CA8238  SOFSHHD12AB0180057
# 141687  TRHEKPR12903CB2404  SODECCR12AB01807EA
# 442227  TRANLMB12903CA8250  SODYJEQ12AB0180054
# 504777  TRPGSSU12903CA8267  SOLDXTH12AB0180077
# 648969  TRLOZZY128F42651C1  SOZJYBK12A8C131267
# 671652  TREASWX128F9326330  SOWNRTJ12AB01817C4
# 704812  TRJQRRU12903CA8252  SOEMWBQ12AB01807E1
# 955403  TRKDDZN12903CD8F63  SOZATBR12AB01874CE
#
#                                               artist  \
# 6558    DJ Lambda feat. Euphoria vs. Solar Explosion
# 8892                                          Lambda
# 70537                                         Lambda
# 141687                                        Lambda
# 442227                                        Lambda
# 504777                                        Lambda
# 648969                                        Lambda
# 671652                                        Lambda
# 704812                                        Lambda
# 955403                                        Lambda
#
#                                          track
# 6558                     Heaven - Original Mix
# 8892                             Hold On Tight
# 70537                            Hold On Tight
# 141687                           Hold On Tight
# 442227                           Hold On Tight
# 504777                           Hold On Tight
# 648969  Hold On Tight (Kaylab + Reeloop Remix)
# 671652                           Hold On Tight
# 704812                           Hold On Tight
# 955403                            La verticale

# %%
df2[df2["artist"].str.contains("The Procussions")]
# Out:
#                    trackId              songId           artist  \
# 141685  TRHEKUZ128F92CD5F7  SOLYRIF12A8C145D57  The Procussions
# 290576  TRFTZSE128F930BBFC  SOYKNTN12AB0183370  The Procussions
#
#                                       track
# 141685                         Miss January
# 290576  That Good Feeling (The Procussions)

# %%
df6 = df2[141688:]

# %%
df6.to_pickle("./song_list6.pkl")
